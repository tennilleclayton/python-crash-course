# %% [markdown]
# ### 7-2: Restaurant Seating
# Write a program that asks the user how many people are in their dinner group. If the answer is more than eight, print a message saying they'll have to wait for a table. Otherwise, report that their table is ready.

# %%
# Ask for the number in dinner group
question = "How many people are in your dinner group? "
group_size = input(question)

# convert to interget
group_size = int(group_size)

print(f"{question}{group_size}\n")

if group_size > 8:
    print("The wait is 15 mins.")
else:
    print("Your table is ready.")
# Out:
# How many people are in your dinner group? 10
# The wait is 15 mins.
