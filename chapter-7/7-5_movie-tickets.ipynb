# %% [markdown]
# # 7-5: Movie Tickets
# A movie theater charges different ticket prices depending on a person's age. If a person is under the age of 3, the ticket is free; if they are between 3 and 12, the ticket is $10; and if they are over age 12, the ticket is $15. Write a loop in which you ask users their age, and then tell them the cost of their movie ticket.

# %%
# Asking ticket goers age
prompt = f"How old are you? "
prompt += f"\n(Enter 'quit' when you are finished) "

while True:
    age = input(prompt)
    print(f"\n{prompt}")

    if age == 'quit':
        break
    
    # Convert age to integer
    age = int(age)

    if age < 3:
        print(f"- Your age is {age}. The ticket is Free.")
    elif age < 13:
        print(f"- Your age is {age}. The ticket is $10.")
    else:
        print(f"- Your age is {age}. The ticket is $15.")
# Out:
# How old are you?
# (Enter 'quit' when you are finished)
# - Your age is 2. The ticket is Free.
#
# How old are you?
# (Enter 'quit' when you are finished)
# - Your age is 3. The ticket is $10.
#
# How old are you?
# (Enter 'quit' when you are finished)
# - Your age is 10. The ticket is $10.
#
# How old are you?
# (Enter 'quit' when you are finished)
# - Your age is 30. The ticket is $15.
#
# How old are you?
# (Enter 'quit' when you are finished)
