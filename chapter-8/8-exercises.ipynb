# %% [markdown]
# # Chapter 8: Functions

# %% [markdown]
# ## 8-1: Message
# Write a function called `display_message()` that prints one sentence telling everyone what you are learning about in this chapter. Call the function, and make sure the message displays correctly.

# %%
def display_message():
    """Display a message about what I've learn in this chapter."""
    print('I have learned how to create functions.')

display_message()
display_message()
# Out:
# I have learned how to create functions.
# I have learned how to create functions.

# %% [markdown]
# ## 8-2: Favorite Book
# Write a function called `favorite_book()` that accepts one parameter, `title`. The function should print a message, such as _One of my favorite books is Alice in Wonderland_. Call the function, making sure to include a book title as an argument in the function call.

# %%
def favorite_book(title):
    """Display Favorite Book title"""
    print(f"One of my favorite books is {title.title()}")

favorite_book("Gone with the wind.")
favorite_book("The Bluest Eye.")
# Out:
# One of my favorite books is Gone With The Wind.
# One of my favorite books is The Bluest Eye.

# %% [markdown]
# ## 8-3: T-Shirt
# Write a function called `make_shirt()` that accepts a size and the text of a message that should be printed on the shirt. The function should print a sentence summarizing the size of the shirt and the message printed on it.
#
# Call the function once using positional arguments to make a shirt. Call the function a second time using keyword arguments.

# %%
def make_shirt(size, message):
    """Display shirt size and message"""
    print(f"Your shirt size is: {size}.")
    print(f"The message on your shirt is: {message}\n")

make_shirt("12", "To Hot to Stop!")
make_shirt(message = "Live Life Love", size = "large")
# Out:
# Your shirt size is: 12.
# The message on your shirt is: To Hot to Stop!
#
# Your shirt size is: large.
# The message on your shirt is: Live Life Love

# %% [markdown]
# ## 8-4: Large Shirts
# Modify the `make_shirt()` function so that shirts are large by default with a message that reads _I love Python_. Make a large shirt and a medium shirt with the default message, and a shirt of any size with a different message.

# %%
def make_shirt(size="large", message="I love Python"):
   """Display shirt size and message"""
   print(f"Your shirt size is: {size}.")
   print(f"The message on your shirt is: {message}\n")

make_shirt()
make_shirt(size="small")
make_shirt("medium","Superman")
# Out:
# Your shirt size is: large.
# The message on your shirt is: I love Python
#
# Your shirt size is: small.
# The message on your shirt is: I love Python
#
# Your shirt size is: medium.
# The message on your shirt is: Superman

# %% [markdown]
# ## 8-5: Cities
# Write a function called `describe_city()` that accepts the name of a _city_ and its _country_. The function should print a simple sentence, such as _Reykjavik is in Iceland_. Give the parameter for the country a default value. Call your function for three different cities, at least one of which is not in the default country.

# %%
def describe_city(city, country = "america"):
    print(f"{city} is in {country.title()}.")

describe_city("Atlanta")
describe_city("Gurugram", "India")
describe_city("London", "England")
# Out:
# Atlanta is in America.
# Gurugram is in India.
# London is in England.

# %% [markdown]
# ## 8-6: City Names
# Write a function called `city_country()` that takes in the name of a **city** and its **country**. The function should return a string formatted like this:
#
# >"Santiago, Chile"
#
# Call your function with at least three city-country pairs, and print the values that are returned.

# %%
def city_country(city, country):
    """Return city country pairs"""
    return f"{city.title()}, {country.title()}"

city = city_country("santiage", "chili")
print(city)

city = city_country("augusta", "america")
print(city)

city = city_country("london", "England")
print(city)
# Out:
# Santiage, Chili
# Augusta, America
# London, England
