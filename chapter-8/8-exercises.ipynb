# %% [markdown]
# # Chapter 8: Functions

# %% [markdown]
# ## 8-1: Message
# Write a function called `display_message()` that prints one sentence telling everyone what you are learning about in this chapter. Call the function, and make sure the message displays correctly.

# %%
def display_message():
    """Display a message about what I've learn in this chapter."""
    print('I have learned how to create functions.')

display_message()
display_message()
# Out:
# I have learned how to create functions.
# I have learned how to create functions.

# %% [markdown]
# ## 8-2: Favorite Book
# Write a function called `favorite_book()` that accepts one parameter, `title`. The function should print a message, such as _One of my favorite books is Alice in Wonderland_. Call the function, making sure to include a book title as an argument in the function call.

# %%
def favorite_book(title):
    """Display Favorite Book title"""
    print(f"One of my favorite books is {title.title()}")

favorite_book("Gone with the wind.")
favorite_book("The Bluest Eye.")
# Out:
# One of my favorite books is Gone With The Wind.
# One of my favorite books is The Bluest Eye.

# %% [markdown]
# ## 8-3: T-Shirt
# Write a function called `make_shirt()` that accepts a size and the text of a message that should be printed on the shirt. The function should print a sentence summarizing the size of the shirt and the message printed on it.
#
# Call the function once using positional arguments to make a shirt. Call the function a second time using keyword arguments.

# %%
def make_shirt(size, message):
    """Display shirt size and message"""
    print(f"Your shirt size is: {size}.")
    print(f"The message on your shirt is: {message}\n")

make_shirt("12", "To Hot to Stop!")
make_shirt(message = "Live Life Love", size = "large")
# Out:
# Your shirt size is: 12.
# The message on your shirt is: To Hot to Stop!
#
# Your shirt size is: large.
# The message on your shirt is: Live Life Love

# %% [markdown]
# ## 8-4: Large Shirts
# Modify the `make_shirt()` function so that shirts are large by default with a message that reads _I love Python_. Make a large shirt and a medium shirt with the default message, and a shirt of any size with a different message.

# %%
def make_shirt(size="large", message="I love Python"):
   """Display shirt size and message"""
   print(f"Your shirt size is: {size}.")
   print(f"The message on your shirt is: {message}\n")

make_shirt()
make_shirt(size="small")
make_shirt("medium","Superman")
# Out:
# Your shirt size is: large.
# The message on your shirt is: I love Python
#
# Your shirt size is: small.
# The message on your shirt is: I love Python
#
# Your shirt size is: medium.
# The message on your shirt is: Superman

# %% [markdown]
# ## 8-5: Cities
# Write a function called `describe_city()` that accepts the name of a _city_ and its _country_. The function should print a simple sentence, such as _Reykjavik is in Iceland_. Give the parameter for the country a default value. Call your function for three different cities, at least one of which is not in the default country.

# %%
def describe_city(city, country = "america"):
    print(f"{city} is in {country.title()}.")

describe_city("Atlanta")
describe_city("Gurugram", "India")
describe_city("London", "England")
# Out:
# Atlanta is in America.
# Gurugram is in India.
# London is in England.

# %% [markdown]
# ## 8-6: City Names
# Write a function called `city_country()` that takes in the name of a **city** and its **country**. The function should return a string formatted like this:
#
# >"Santiago, Chile"
#
# Call your function with at least three city-country pairs, and print the values that are returned.

# %%
def city_country(city, country):
    """Return city country pairs"""
    return f"{city.title()}, {country.title()}"

city = city_country("santiage", "chili")
print(city)

city = city_country("augusta", "america")
print(city)

city = city_country("london", "England")
print(city)
# Out:
# Santiage, Chili
# Augusta, America
# London, England

# %% [markdown]
# ## 8-7: Album
# Write a function called `make_album()` that builds a dictionary describing a music album. The function should take in an _artist name_ and an _album title_, and it should return a dictionary containing these two pieces of information. Use the function to make three dictionaries representing different albums. Print each return value to show that the dictionaries are storing the album information correctly.
#
# Use `None` to add an optional parameter to `make_album()` that allows you to store the number of songs on an album. If the calling line includes a value for the number of songs, add that value to the album’s dictionary. Make at least one new function call that includes the number of songs on an album.

# %%
def make_album(artist_name, album_title, singles=None):
    """Returns music album information"""

    album_dict = {'artist name': artist_name, 'album title': album_title}
    if singles:
        album_dict['singles'] = singles

    return album_dict

album = make_album("jill scott","Who Is Jill Scott?", 10)
print(album)

album = make_album("Eric Benét", "True to Myself")
print(album)

album = make_album("Taylor Swift", "Fearless")
print(album)
# Out:
# {'artist name': 'jill scott', 'album title': 'Who Is Jill Scott?', 'singles': 10}
# {'artist name': 'Eric Benét', 'album title': 'True to Myself'}
# {'artist name': 'Taylor Swift', 'album title': 'Fearless'}

# %% [markdown]
# ## 8-8: User Albums
# Start with your program from Exercise 8-7. Write a while loop that allows users to enter an album's artist and title. Once you have that information, call `make_album()` with the user's input and print the dictionary that's created. Be sure to include a _quit value_ in the while loop.

# %%
def make_album(name, title):
    """Returns music album information"""
    album_dict = {
        'artist name': name, 
        'album title': title}

    return album_dict

print(f"\nPlease enter an album's artist and title:")
print(f"(enter 'q' at any time to quit)\n")

while True:
    a_name = input("Artist name: ")
    if a_name == "q":
        break

    a_title = input("Album title: ")
    if a_title =="q":
        break

    add_to_album = make_album(a_name, a_title)
    print(add_to_album)

print("\nThank you for your response.")
# Out:
# Please enter an album's artist and title:
# (enter 'q' at any time to quit)
#
# {'artist name': 'Taylor Swift', 'album title': 'Fearless'}
# {'artist name': 'Eric Benét', 'album title': 'True to Myself'}
#
# Thank you for your response.

# %% [markdown]
# ## 8-9: Messages
# Make a list containing a series of short text messages. Pass the list to a function called `show_messages()`, which prints each text message.

# %%
def show_messages(messages):
    """Displays a list of short messages"""
    for message in messages:
        mgs = f"- {message}"
        print(mgs)

messages = [
    "Morbi vulputate ante et sapien maximus, quis sodales massa dapibus.", 
    "Suspendisse malesuada quam at efficitur imperdiet.", 
    "Praesent cursus nisi ut rutrum fringilla."]

show_messages(messages)
# Out:
# - Morbi vulputate ante et sapien maximus, quis sodales massa dapibus.
# - Suspendisse malesuada quam at efficitur imperdiet.
# - Praesent cursus nisi ut rutrum fringilla.

# %% [markdown]
# ## 8-10: Sending Messages
# Start with a copy of your program from Exercise 8-9. Write a function called `send_messages()` that prints each text message and moves each message to a new list called `sent_messages` as it’s printed. After calling the function, print both of your lists to make sure the messages were moved correctly.

# %%
def show_messages(messages):
    """Displays a list of short messages"""
    while messages:
        current_message = messages.pop()
        print(f"Current message: {current_message}")
        sent_messages.append(current_message)

messages = [
    "the cow", 
    "jumped over", 
    "the moon"]

sent_messages = []

show_messages(messages)

print(f"\n**** Sent Messages ****")
for sent_message in sent_messages:
    print(f"- {sent_message}")

print(f"\nmessages list: {messages}")
print(f"sent messages list: {sent_messages}")
# Out:
# Current message: the moon
# Current message: jumped over
# Current message: the cow
#
# **** Sent Messages ****
# - the moon
# - jumped over
# - the cow
#
# messages list: []
# sent messages list: ['the moon', 'jumped over', 'the cow']

# %% [markdown]
# ## 8-11: Archived Messages
# Start with your work from Exercise 8-10. Call the function `send_messages()` with a copy of the list of messages. After calling the function, print both of your lists to show that the original list has retained its messages.

# %%
def show_messages(messages):
    """Displays a list of short messages"""
    while messages:
        current_message = messages.pop()
        print(f"Current message: {current_message}")
        sent_messages.append(current_message)

messages = [
    "the cow", 
    "jumped over", 
    "the moon"]

sent_messages = []

show_messages(messages[:]) # function_name(list_name[:]) keeps original list unchanged

print(f"\n**** Sent Messages ****")
for sent_message in sent_messages:
    print(f"- {sent_message}")

print(f"\nmessages list: {messages}")
print(f"sent messages list: {sent_messages}")
# Out:
# Current message: the moon
# Current message: jumped over
# Current message: the cow
#
# **** Sent Messages ****
# - the moon
# - jumped over
# - the cow
#
# messages list: ['the cow', 'jumped over', 'the moon']
# sent messages list: ['the moon', 'jumped over', 'the cow']

# %% [markdown]
# ## 8-12: Sandwiches
# Write a function that accepts a list of items a person wants on a sandwich. The function should have one parameter that collects as many items as the function call provides, and it should print a summary of the sandiwch that is being ordered. Call the function three tiems, using a different number of arguments each time.

# %%
def make_sandwich(*items):
    """Building a sandiwch"""
    print(f"\nWe're making your sandwich:")

    for item in items:
        print(f"- {item.title()} added.")

    print(f"Your sandwich is ready!")

make_sandwich("ham")
make_sandwich("Tofu", "pepper jack cheese")
make_sandwich("smoked turkey", "americen cheese", "lettuce", "tomato")
# Out:
# We're making your sandwich:
# - Ham added.
# Your sandwich is ready!
#
# We're making your sandwich:
# - Tofu added.
# - Pepper Jack Cheese added.
# Your sandwich is ready!
#
# We're making your sandwich:
# - Smoked Turkey added.
# - Americen Cheese added.
# - Lettuce added.
# - Tomato added.
# Your sandwich is ready!
