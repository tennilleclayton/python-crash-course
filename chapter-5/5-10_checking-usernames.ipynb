# %% [markdown]
# # 5-10: Checking Usernames
#
# Do the following to create a program that simulates how websites ensure that everyone has a unique username.
#
# - Make a list of five or more usernames called _current_users_. Make another list of five usernames called _new_users_. Make sure one or two of the new usernames are also in the _current_users_ list.
# - Loop through the _new_users_ list to see if each new username has already been used. If it has, print a message that the person will need to enter a new username. If a username has not been used, print a message saying that the username is available.
# - Make sure your comparison is case insensitive. If `'John'` has been used, `'JOHN'` should not be accepted. (To do this, you’ll need to make a copy of _current_users_ containing the lowercase versions of all existing users.)

# %%
# User lists
current_users = ["StarPixelStudio","JadeNovaCreative","BrightPathDesigns",
                 "DigitalBloomCo","UrbanSparkMedia","JohhnyBoi"]
new_users = ["TechSavvyTenn","LuxeLogicStudio","BrightPathDesigns",
             "BoldNestCreative","starpixelstudio","johhnyboi","hadesgirl"]

# compare case insensitive
current_users_case = []
for user in current_users:
    current_users_case.append(user.lower())

for new_user in new_users:
    if new_user.lower() in current_users_case:
        print(f"{new_user} is taken. Enter a new username.")
    else:
        print(f"{new_user} is available.")
# Out:
# TechSavvyTenn is available.
# LuxeLogicStudio is available.
# BrightPathDesigns is taken. Enter a new username.
# BoldNestCreative is available.
# starpixelstudio is taken. Enter a new username.
# johhnyboi is taken. Enter a new username.
# hadesgirl is available.

# %%
# List Comprehension
current_users_case2 = [user.lower() for user in current_users]

print(current_users_case2)
# Out:
# ['starpixelstudio', 'jadenovacreative', 'brightpathdesigns', 'digitalbloomco', 'urbansparkmedia', 'johhnyboi']
