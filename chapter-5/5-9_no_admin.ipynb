# %% [markdown]
# # 5-9: No Users
#
# Add an `if` statement test to hello_admin.py to make sure the list of users is not empty.
#
# - If the list is emtpy, print the message We need to find some users!
# - Remove all of the usernames from your list, and make sure the correct message is printed.

# %%
# username list
usernames = ['jondon19','supperjoey','janeHello312','ladyred_gsn','admin','supermanclark']

# %%
# Greeting
for user in usernames:
    print(f"Welcome, {user}!")
# Out:
# Welcome, jondon19!
# Welcome, supperjoey!
# Welcome, janeHello312!
# Welcome, ladyred_gsn!
# Welcome, admin!
# Welcome, supermanclark!

# %%
# Greet the admin
for user in usernames:
    if user == "admin":
        print(f"Hello {user}, would you like to see a status report?")
    else:
        print(f"Hello {user}, thank you for loggin in again.")
# Out:
# Hello jondon19, thank you for loggin in again.
# Hello supperjoey, thank you for loggin in again.
# Hello janeHello312, thank you for loggin in again.
# Hello ladyred_gsn, thank you for loggin in again.
# Hello admin, would you like to see a status report?
# Hello supermanclark, thank you for loggin in again.

# %%
# test for empty usernames list
if usernames:
    for user in usernames:
        if user == "admin":
            print(f"Hello {user}, would you like to see a status report?")
        else:
            print(f"Hello {user}, thank you for loggin in again.")
else:
    print("We need to find some users!")
# Out:
# Hello jondon19, thank you for loggin in again.
# Hello supperjoey, thank you for loggin in again.
# Hello janeHello312, thank you for loggin in again.
# Hello ladyred_gsn, thank you for loggin in again.
# Hello admin, would you like to see a status report?
# Hello supermanclark, thank you for loggin in again.

# %%
# remove usernames
usernames = []
# print(usernames) # verify empty username list
if usernames:
    for user in usernames:
        if user == "admin":
            print(f"Hello {user}, would you like to see a status report?")
        else:
            print(f"Hello {user}, thank you for loggin in again.")
else:
    print("We need to find some users!")
# Out:
# We need to find some users!
