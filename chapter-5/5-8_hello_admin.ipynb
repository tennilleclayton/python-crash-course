# %% [markdown]
# # 5-8: Hello Admin
#
# Make a list of five or more usernames, including the name `admin`. Imagine you are writing code that will print a greeting to each user after they log in to a website. Loop through the list, and print a greeting to each user.
#
# - If the username is `admin`, print a special greeting, such as Hello admin, would you like to see a status report?
# - Otherwise, print a generic greeting, such as Hello Jaden, thank you for loggin in again.

# %%
# username list
usernames = ['jondon19','supperjoey','janeHello312','ladyred_gsn','admin','supermanclark']

# %%
# Greeting
for user in usernames:
    print(f"Welcome, {user}!")
# Out:
# Welcome, jondon19!
# Welcome, supperjoey!
# Welcome, janeHello312!
# Welcome, ladyred_gsn!
# Welcome, admin!
# Welcome, supermanclark!

# %%
# Greet the admin
for user in usernames:
    if user == "admin":
        print(f"Hello {user}, would you like to see a status report?")
    else:
        print(f"Hello {user}, thank you for loggin in again.")
# Out:
# Hello jondon19, thank you for loggin in again.
# Hello supperjoey, thank you for loggin in again.
# Hello janeHello312, thank you for loggin in again.
# Hello ladyred_gsn, thank you for loggin in again.
# Hello admin, would you like to see a status report?
# Hello supermanclark, thank you for loggin in again.
