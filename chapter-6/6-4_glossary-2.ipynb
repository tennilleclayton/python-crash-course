# %% [markdown]
# # 6-4: Glossary 2
# Now that you know how to loop through a dictionary, clean up the code from Exercise 6-3 (page 99) by replacing your series of `print()` calls with a loop that runs through the dictionary's keys and values. When you're sure that your loop works, add five more Python terms to your glossary. When you run your program again, these new words and meanings should automatically be included in the output.

# %%
# Glossary dictionary
glossary = {
    'variables': 'containers for storing data values.', 
    'strings': 'sequence of characters written inside quotes.',
    'tuple': 'an ordered, and unchangeable, collection.',
    'lists': 'an ordered, and changeable, collection.',
    'comments': 'code lines that will not be executed.',
    }

# %%
# Add to Dictionary
glossary['dictionary'] = 'a collection which is unordered, changeable and indexed.'
glossary['syntax'] = 'the set of rules that defines how code is written, structured, and interpreted.'
glossary['keywords'] = 'reserved words that have special meanings and serve specific purposes in the language syntax.'

# %%
# Loop
for term, meaning in glossary.items():
    print(f"{term.title()} - {meaning.capitalize()}\n")
# Out:
# Variables - Containers for storing data values.
#
# Strings - Sequence of characters written inside quotes.
#
# Tuple - An ordered, and unchangeable, collection.
#
# Lists - An ordered, and changeable, collection.
#
# Comments - Code lines that will not be executed.
#
# Dictionary - A collection which is unordered, changeable and indexed.
#
# Syntax - The set of rules that defines how code is written, structured, and interpreted.
#
# Keywords - Reserved words that have special meanings and serve specific purposes in the language syntax.
